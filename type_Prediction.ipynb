# %% [markdown]
# ## Importing the necessary libraries

# %%
## For storing the data into dataframes and all
import pandas as pd
## For numerical computations
import numpy as np
## For visualising purpose
import matplotlib.pyplot as plt
# To make this notebook's output stable across runs
np.random.seed(42)
## For visualisation purpose
import seaborn as sns
import warnings

## For Speech to Text conversion
import speech_recognition as sr

# %% [markdown]
# ## Importing the dataset

# %%
songs = pd.read_csv("data.csv")

songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2017 entries, 0 to 2016
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        2017 non-null   int64
#  1   acousticness      2017 non-null   float64
#  2   danceability      2017 non-null   float64
#  3   duration_ms       2017 non-null   int64
#  4   energy            2017 non-null   float64
#  5   instrumentalness  2017 non-null   float64
#  6   key               2017 non-null   int64
#  7   liveness          2017 non-null   float64
#  8   loudness          2017 non-null   float64
#  9   mode              2017 non-null   int64
#  10  speechiness       2017 non-null   float64
#  11  tempo             2017 non-null   float64
#  12  time_signature    2017 non-null   float64
#  13  valence           2017 non-null   float64
#  14  target            2017 non-null   int64
#  15  song_title        2017 non-null   object
#  16  artist            2017 non-null   object
# dtypes: float64(10), int64(5), object(2)
# memory usage: 268.0+ KB

# %%
songs.describe()
# Out:
#         Unnamed: 0  acousticness  danceability   duration_ms       energy  \
# count  2017.000000   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean   1008.000000      0.187590      0.618422  2.463062e+05     0.681577
# std     582.402066      0.259989      0.161029  8.198181e+04     0.210273
# min       0.000000      0.000003      0.122000  1.604200e+04     0.014800
# 25%     504.000000      0.009630      0.514000  2.000150e+05     0.563000
# 50%    1008.000000      0.063300      0.631000  2.292610e+05     0.715000
# 75%    1512.000000      0.265000      0.738000  2.703330e+05     0.846000
# max    2016.000000      0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# 25%            0.000000     2.000000     0.092300    -8.394000     0.000000
# 50%            0.000076     6.000000     0.127000    -6.248000     1.000000
# 75%            0.054000     9.000000     0.247000    -4.746000     1.000000
# max            0.976000    11.000000     0.969000    -0.307000     1.000000
#
#        speechiness        tempo  time_signature      valence       target
# count  2017.000000  2017.000000     2017.000000  2017.000000  2017.000000
# mean      0.092664   121.603272        3.968270     0.496815     0.505702
# std       0.089931    26.685604        0.255853     0.247195     0.500091
# min       0.023100    47.859000        1.000000     0.034800     0.000000
# 25%       0.037500   100.189000        4.000000     0.295000     0.000000
# 50%       0.054900   121.427000        4.000000     0.492000     1.000000
# 75%       0.108000   137.849000        4.000000     0.691000     1.000000
# max       0.816000   219.331000        5.000000     0.992000     1.000000

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# examining the correlation between different features

corr_metrics=songs.corr()
corr_metrics.style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col0,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col1,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col2,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col4,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row5_col5,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row6_col6,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row7_col7,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row8_col8,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row9_col9,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row10_col10,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row11_col11,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row12_col12,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row13_col13,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row14_col14{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col1,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row8_col0{
#             background-color:  #7eadd1;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col2{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col6,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row7_col11,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row9_col13,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row13_col9{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col4,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col5{
#             background-color:  #a8bedc;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col5,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col8,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col2,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row12_col6{
#             background-color:  #dfddec;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col7{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col8,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row14_col5{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col9,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row7_col10,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row8_col10,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row10_col13,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row12_col5{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col10,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col7,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col11{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col11,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col13,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col9,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col9,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row5_col12,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row9_col7,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row14_col9{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col12{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row0_col14,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col2,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col4,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col8,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col12,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col7,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col11,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col1,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row5_col10,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row5_col13,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row6_col9,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row8_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row8_col5,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row9_col6,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row14_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col0{
#             background-color:  #62a2cb;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col11,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row10_col2,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row13_col12{
#             background-color:  #c9cee4;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col6{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col9{
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col10{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col13{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row1_col14,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col13{
#             background-color:  #9ebad9;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col0{
#             background-color:  #a1bbda;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col1{
#             background-color:  #c5cce3;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row4_col10{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col4,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row10_col8,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row14_col4{
#             background-color:  #96b6d7;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col5{
#             background-color:  #e3e0ee;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col6,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col6,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row6_col12,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row12_col3,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row13_col10{
#             background-color:  #e0dded;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col8{
#             background-color:  #91b5d6;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col9,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row10_col9{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col10{
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col12,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row14_col10{
#             background-color:  #cacee5;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col13{
#             background-color:  #63a2cb;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row2_col14,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row13_col4{
#             background-color:  #569dc8;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col0,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row5_col0{
#             background-color:  #99b8d8;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col1,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row6_col4,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row9_col1,#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row12_col0{
#             background-color:  #8eb3d5;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col2{
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }#T_2dc80c1b_c961_11ec_91db_38baf89c76e1row3_col4{

# %%
# Removing the unwanted columns 

features=songs.drop(columns=["song_title","artist","Unnamed: 0"])
features.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.0102         0.833       204600   0.434          0.021900    2
# 1        0.1990         0.743       326933   0.359          0.006110    1
# 2        0.0344         0.838       185707   0.412          0.000234    2
# 3        0.6040         0.494       199413   0.338          0.510000    5
# 4        0.1800         0.678       392893   0.561          0.512000    5
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.1650    -8.795     1       0.4310  150.062             4.0    0.286
# 1    0.1370   -10.401     1       0.0794  160.083             4.0    0.588
# 2    0.1590    -7.148     1       0.2890   75.044             4.0    0.173
# 3    0.0922   -15.236     1       0.0261   86.468             4.0    0.230
# 4    0.4390   -11.648     0       0.0694  174.004             4.0    0.904
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
features.describe()
# Out:
#        acousticness  danceability   duration_ms       energy  \
# count   2017.000000   2017.000000  2.017000e+03  2017.000000
# mean       0.187590      0.618422  2.463062e+05     0.681577
# std        0.259989      0.161029  8.198181e+04     0.210273
# min        0.000003      0.122000  1.604200e+04     0.014800
# 25%        0.009630      0.514000  2.000150e+05     0.563000
# 50%        0.063300      0.631000  2.292610e+05     0.715000
# 75%        0.265000      0.738000  2.703330e+05     0.846000
# max        0.995000      0.984000  1.004627e+06     0.998000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       2017.000000  2017.000000  2017.000000  2017.000000  2017.000000
# mean           0.133286     5.342588     0.190844    -7.085624     0.612295
# std            0.273162     3.648240     0.155453     3.761684     0.487347
# min            0.000000     0.000000     0.018800   -33.097000     0.000000
# 25%            0.000000     2.000000     0.092300    -8.394000     0.000000
# 50%            0.000076     6.000000     0.127000    -6.248000     1.000000
# 75%            0.054000     9.000000     0.247000    -4.746000     1.000000
# max            0.976000    11.000000     0.969000    -0.307000     1.000000
#
#        speechiness        tempo  time_signature      valence       target
# count  2017.000000  2017.000000     2017.000000  2017.000000  2017.000000
# mean      0.092664   121.603272        3.968270     0.496815     0.505702
# std       0.089931    26.685604        0.255853     0.247195     0.500091
# min       0.023100    47.859000        1.000000     0.034800     0.000000
# 25%       0.037500   100.189000        4.000000     0.295000     0.000000
# 50%       0.054900   121.427000        4.000000     0.492000     1.000000
# 75%       0.108000   137.849000        4.000000     0.691000     1.000000
# max       0.816000   219.331000        5.000000     0.992000     1.000000

# %% [markdown]
# # Feature Scaling

# %%
from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()


loudness = features[['loudness']].values
key = features[['key']].values
tempo = features[['tempo']].values
time_signature = features[['time_signature']].values
duration_ms = features[['duration_ms']].values


features[['loudness']] = min_max_scaler.fit_transform(loudness)
features[['key']] = min_max_scaler.fit_transform(key)
features[['tempo']]= min_max_scaler.fit_transform(tempo)
features[['time_signature']]= min_max_scaler.fit_transform(time_signature)
features[['duration_ms']] = min_max_scaler.fit_transform(duration_ms)

# %%
features.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  \
# 0        0.0102         0.833     0.190735   0.434          0.021900
# 1        0.1990         0.743     0.314481   0.359          0.006110
# 2        0.0344         0.838     0.171624   0.412          0.000234
# 3        0.6040         0.494     0.185488   0.338          0.510000
# 4        0.1800         0.678     0.381202   0.561          0.512000
#
#         key  liveness  loudness  mode  speechiness     tempo  time_signature  \
# 0  0.181818    0.1650  0.741141     1       0.4310  0.596033            0.75
# 1  0.090909    0.1370  0.692162     1       0.0794  0.654474            0.75
# 2  0.181818    0.1590  0.791369     1       0.2890  0.158539            0.75
# 3  0.454545    0.0922  0.544709     1       0.0261  0.225162            0.75
# 4  0.454545    0.4390  0.654132     0       0.0694  0.735659            0.75
#
#    valence  target
# 0    0.286       1
# 1    0.588       1
# 2    0.173       1
# 3    0.230       1
# 4    0.904       1

# %% [markdown]
# ## Performing Feature Reduction

# %%
#Feature Reduction as with the help of this graph we can see the features having high variance
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(features)
xfeatures = range(pca.n_components_)
plt.bar(xfeatures,pca.explained_variance_)
plt.xticks(xfeatures)
plt.xlabel('PCA Features')
plt.ylabel('variance')
plt.show()

# %%
# So from above we can see five features are having high variance so we can remove the unwanted features
features=features.drop(columns=["duration_ms","energy","instrumentalness","key","mode","tempo","time_signature","valence","target"])
features.head()
# Out:
#    acousticness  danceability  liveness  loudness  speechiness
# 0        0.0102         0.833    0.1650  0.741141       0.4310
# 1        0.1990         0.743    0.1370  0.692162       0.0794
# 2        0.0344         0.838    0.1590  0.791369       0.2890
# 3        0.6040         0.494    0.0922  0.544709       0.0261
# 4        0.1800         0.678    0.4390  0.654132       0.0694

# %%
features.hist(bins=50,figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'acousticness'}>,
#         <AxesSubplot:title={'center':'danceability'}>],
#        [<AxesSubplot:title={'center':'liveness'}>,
#         <AxesSubplot:title={'center':'loudness'}>],
#        [<AxesSubplot:title={'center':'speechiness'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Now we will try to cluster the songs on the basis of emotion of the songs

# %%
## For clustering we will be KMeans Clustering for that first we need to know the optimum number of clusters
#import the required model
from sklearn.cluster import KMeans
#Within Cluster Sum Of Square to evaluate the efficiency of a model
wcss = []

# %% [markdown]
# ## Now we will try predicting values using different number of clusters and store the result in wcss array¶

# %%
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k,random_state=42,max_iter=300)
    km = km.fit(features)
    wcss.append(km.inertia_)

# %%
##It gives an idea of how well the objects are classified taking that number of clusters
from sklearn.metrics import silhouette_score
for n_clusters in range(2,15):
    clusterer = KMeans (n_clusters=n_clusters)
    preds = clusterer.fit_predict(features)
    centers = clusterer.cluster_centers_

    score = silhouette_score (features, preds, metric='euclidean')
    print ("For n_clusters = {}, silhouette score is {})".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.4824337334937478)
# For n_clusters = 3, silhouette score is 0.28933487266645563)
# For n_clusters = 4, silhouette score is 0.2618294502365973)
# For n_clusters = 5, silhouette score is 0.27004553080113314)
# For n_clusters = 6, silhouette score is 0.25900596298589357)
# For n_clusters = 7, silhouette score is 0.2562116727768139)
# For n_clusters = 8, silhouette score is 0.22161191374042372)
# For n_clusters = 9, silhouette score is 0.23271911186600397)
# For n_clusters = 10, silhouette score is 0.2342243399954953)
# For n_clusters = 11, silhouette score is 0.22709473702842317)
# For n_clusters = 12, silhouette score is 0.22831843105593103)
# For n_clusters = 13, silhouette score is 0.19528862666729244)
# For n_clusters = 14, silhouette score is 0.2283626520262163)

# %% [markdown]
# ## Plotting the wcss against number of clusters to use elbow method to determine optimal number of clusters

# %%
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(K, wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
# Within cluster sum of squares
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### So the optimal number of clusters seems to be 4 as elbow method was depicting 5 while silhouette_score was giving a better value with 4

# %%
## Standardize the data and fit that standardized data to KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
scaler = StandardScaler()
kmeans = KMeans(n_clusters=4)

# %%
## Made a pipeline to perform these tasks together
from sklearn.pipeline import make_pipeline
pipeline = make_pipeline(scaler,KMeans(n_clusters=4,init='k-means++',random_state=3222,max_iter=300))
pipeline.fit(features)
labels = pipeline.predict(features)
label_df = pd.DataFrame(labels)
np.shape(label_df)
features[['cluster_labels']] = label_df
features[['song_title']] = songs[['song_title']]
features[['artist']] = songs[['artist']]
features.head(10)
# Out:
#    acousticness  danceability  liveness  loudness  speechiness  \
# 0       0.01020         0.833    0.1650  0.741141       0.4310
# 1       0.19900         0.743    0.1370  0.692162       0.0794
# 2       0.03440         0.838    0.1590  0.791369       0.2890
# 3       0.60400         0.494    0.0922  0.544709       0.0261
# 4       0.18000         0.678    0.4390  0.654132       0.0694
# 5       0.00479         0.804    0.1640  0.805581       0.1850
# 6       0.01450         0.739    0.2070  0.667673       0.1560
# 7       0.02020         0.266    0.1600  0.655322       0.0371
# 8       0.04810         0.603    0.3420  0.898780       0.3470
# 9       0.00208         0.836    0.5710  0.771729       0.2370
#
#    cluster_labels         song_title            artist
# 0               3           Mask Off            Future
# 1               0            Redbone  Childish Gambino
# 2               3       Xanny Family            Future
# 3               2     Master Of None       Beach House
# 4               1     Parallel Lines       Junior Boys
# 5               3           Sneakin’             Drake
# 6               0        Childs Play             Drake
# 7               0    Gyöngyhajú lány             Omega
# 8               3  I've Seen Footage       Death Grips
# 9               1     Digital Animal       Honey Claws

# %% [markdown]
# ## Performing Dimensionality Reduction for properly visualizing the data

# %%
# PCA to reduce our data to 2 dimensions for visualisation
from sklearn.decomposition import PCA
yfeatures = features.iloc[:,0:5]
kmeans.fit(yfeatures)
y_kmeans = kmeans.predict(yfeatures)
pca = PCA(n_components=2)
principal_components = pca.fit_transform(yfeatures)

# %%
pc = pd.DataFrame(principal_components)
pc['label'] = y_kmeans
pc.columns = ['x', 'y','label']

#plot data with seaborn
cluster = sns.lmplot(data=pc, x='x', y='y', hue='label', 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Users\Pravallika Myneni\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\regression.py:592: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
#Explained variance ratio will return the value for components
pca.explained_variance_ratio_
# Out:
# array([0.53393903, 0.20432391])

# %%
# Dump components relations with features:
print (pd.DataFrame(pca.components_,columns=yfeatures.columns,index = ['PC-1','PC-2']))
# Out:
#       acousticness  danceability  liveness  loudness  speechiness
# PC-1      0.944877     -0.153574 -0.095453 -0.269430    -0.043790
# PC-2     -0.036965     -0.746174  0.660915  0.065866    -0.026653

# %% [markdown]
# # Figuring out what the different clusters contain

# %%
#Counting the number of songs in each cluster
features = features.sample(frac=1)
features['cluster_labels'].value_counts()
# Out:
# 0    1200
# 1     352
# 2     239
# 3     226
# Name: cluster_labels, dtype: int64

# %%
#Analysing the first cluster
features[features['cluster_labels']==0].head(15)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 38        0.012800         0.747    0.1260  0.852699       0.1260
# 461       0.000022         0.657    0.0525  0.865477       0.0297
# 695       0.029600         0.907    0.1050  0.745349       0.0549
# 1246      0.199000         0.422    0.1890  0.789814       0.0306
# 337       0.011500         0.820    0.0820  0.752364       0.0361
# 239       0.017200         0.496    0.1300  0.792193       0.0324
# 155       0.023300         0.738    0.3090  0.818878       0.0822
# 204       0.000467         0.817    0.0911  0.807990       0.0399
# 1934      0.265000         0.793    0.2070  0.861116       0.0405
# 85        0.019200         0.619    0.0771  0.723727       0.0343
# 1446      0.005760         0.396    0.1160  0.892681       0.1040
# 1992      0.007490         0.446    0.1300  0.876151       0.0545
# 756       0.370000         0.645    0.1250  0.788869       0.1590
# 1445      0.098700         0.443    0.1180  0.851662       0.0984
# 715       0.017500         0.764    0.2300  0.747088       0.0576
#
#       cluster_labels                                         song_title  \
# 38                 0                                               7/11
# 461                0         Danger! High Voltage (Soulchild Radio Mix)
# 695                0  Music Is the Answer - Original Extended 12-Inc...
# 1246               0                                   I Have This Hope
# 337                0  Let's Lovedance Tonight - Danny Krivit Re-edit...
# 239                0                           Hold On We're Going Home
# 155                0                                              Annie
# 204                0                                  Le Goudron (Edit)
# 1934               0                                 Whenever, Wherever
# 85                 0                                        I'm In Love
# 1446               0                              Mantra - Mat Zo Remix
# 1992               0                                           Portugal
# 756                0                                    Hell Of A Night
# 1445               0                 Freesol (feat. Skyler Stonestreet)
# 715                0                                       Tennis Court
#
#                   artist
# 38               Beyoncé
# 461         Electric Six
# 695               Celeda
# 1246  Tenth Avenue North
# 337          Gary's Gang
# 239                 ASTR
# 155          Neon Indian
# 204                YACHT
# 1934             Shakira
# 85           Fool's Gold
# 1446              Noisia
# 1992       WALK THE MOON
# 756          ScHoolboy Q
# 1445         Seven Lions
# 715                Lorde

# %%
features[features['cluster_labels']==0].mean()
# Out:
# acousticness      0.111980
# danceability      0.648952
# liveness          0.126449
# loudness          0.813033
# speechiness       0.063902
# cluster_labels    0.000000
# dtype: float64

# %%
#Analysing the second cluster
features[features['cluster_labels']==1].head(10)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 989       0.001900         0.468     0.409  0.854254       0.0570
# 233       0.077800         0.729     0.382  0.816072       0.0708
# 993       0.055900         0.521     0.267  0.910704       0.0336
# 688       0.093800         0.874     0.409  0.818146       0.1020
# 123       0.000758         0.695     0.302  0.907777       0.1930
# 2005      0.021600         0.526     0.426  0.902440       0.0875
# 1426      0.007550         0.540     0.642  0.892742       0.1380
# 1779      0.038200         0.518     0.289  0.847545       0.0313
# 1167      0.030300         0.415     0.383  0.703050       0.0741
# 417       0.005250         0.555     0.346  0.770235       0.0353
#
#       cluster_labels                           song_title          artist
# 989                1                         Five Seconds     Twin Shadow
# 233                1                           Sanctified       Rick Ross
# 993                1                  Never Saw The Point           Cults
# 688                1                               Shabba       A$AP Ferg
# 123                1              Movin' Bass - GTA Remix       Rick Ross
# 2005               1             Spoon Me - Slushii Remix       Elliphant
# 1426               1         Game Ain't Based On Sympathy       Rick Ross
# 1779               1  Summer Is Over feat. Sara Bareilles  Jon McLaughlin
# 1167               1                              Selfish          Future
# 417                1                     Cry Like A Ghost     Passion Pit

# %%
features[features['cluster_labels']==1].mean()
# Out:
# acousticness      0.061627
# danceability      0.544060
# liveness          0.444972
# loudness          0.850135
# speechiness       0.087751
# cluster_labels    1.000000
# dtype: float64

# %%
#Analysing the third cluster
features[features['cluster_labels']==2].head(10)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 1554         0.960         0.411    0.0640  0.300915       0.0414
# 1784         0.789         0.764    0.0997  0.765996       0.0643
# 822          0.666         0.827    0.1230  0.673681       0.0352
# 1528         0.988         0.479    0.1030  0.572675       0.0351
# 1536         0.921         0.445    0.1310  0.478652       0.0374
# 718          0.717         0.345    0.1000  0.701403       0.0681
# 872          0.809         0.833    0.0952  0.816468       0.0430
# 1257         0.627         0.295    0.1570  0.822568       0.0318
# 1364         0.712         0.483    0.0975  0.889814       0.0261
# 1540         0.823         0.526    0.1140  0.610186       0.0411
#
#       cluster_labels                song_title             artist
# 1554               2        Where Do You Start  Brad Mehldau Trio
# 1784               2          Simple Love Song             Anuhea
# 822                2                 Black Boy       Pops Staples
# 1528               2              I Got It Bad  Enrico Pieranunzi
# 1536               2  It Never Entered my Mind     Mulgrew Miller
# 718                2               Hannah Hunt    Vampire Weekend
# 872                2         Oogum Boogum Song       Brenton Wood
# 1257               2                On My Side   Kim Walker-Smith
# 1364               2                    Wonder       Standing Egg
# 1540               2    Good Morning Heartache     Scott Hamilton

# %%
features[features['cluster_labels']==2].mean()
# Out:
# acousticness      0.766538
# danceability      0.505531
# liveness          0.151328
# loudness          0.605591
# speechiness       0.046080
# cluster_labels    2.000000
# dtype: float64

# %%
#Analysing the third cluster
features[features['cluster_labels']==3].head(10)
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 141       0.001020         0.798    0.0271  0.816163        0.263
# 1497      0.242000         0.592    0.0715  0.907685        0.366
# 1804      0.122000         0.498    0.1060  0.828332        0.310
# 1962      0.058800         0.653    0.1940  0.816529        0.211
# 1181      0.330000         0.736    0.0898  0.659805        0.425
# 37        0.056500         0.853    0.3410  0.779567        0.194
# 1014      0.375000         0.561    0.0840  0.776731        0.413
# 968       0.000954         0.775    0.1440  0.823605        0.271
# 644       0.152000         0.702    0.2200  0.497194        0.342
# 1951      0.267000         0.563    0.2430  0.820586        0.325
#
#       cluster_labels                         song_title  \
# 141                3                   Gold and a Pager
# 1497               3  Go For Broke (feat. James Arthur)
# 1804               3                        Dear No One
# 1962               3                    Mysterious Girl
# 1181               3                           Location
# 37                 3                            Jumpman
# 1014               3              And Dat (Ft. Stormzy)
# 968                3                     Black Skinhead
# 644                3                    Ride The Rhythm
# 1951               3           Can I Touch You...There?
#
#                                          artist
# 141                               The Cool Kids
# 1497                          Machine Gun Kelly
# 1804                                 Tori Kelly
# 1962                                Peter Andre
# 1181                                     Khalid
# 37                                        Drake
# 1014                                     Bonkaz
# 968                                  Kanye West
# 644   On The House featuring Marshall Jefferson
# 1951                             Michael Bolton

# %%
features[features['cluster_labels']==3].mean()
# Out:
# acousticness      0.172998
# danceability      0.691518
# liveness          0.178742
# loudness          0.798253
# speechiness       0.302301
# cluster_labels    3.000000
# dtype: float64

# %%
## On analysing the mean feature values of the clusters following mood can be assigned to a song belonging to the particular clusterfeatures[features['cluster_labels']==0]:
mapping={0 : "Feeling energetic",1 : "Feeling Happy", 2:"Feeling passionate",3: "Feeling Calm"}
features['cluster_labels'] = [mapping[i] for i in features['cluster_labels']]
features.tail()
# Out:
#       acousticness  danceability  liveness  loudness  speechiness  \
# 2004        0.0969         0.595    0.1020  0.938030       0.3640
# 1194        0.5550         0.635    0.0970  0.861086       0.2580
# 780         0.0505         0.794    0.0562  0.786307       0.4200
# 1361        0.4980         0.587    0.1060  0.789418       0.0424
# 1117        0.0760         0.899    0.0631  0.880421       0.2920
#
#          cluster_labels                        song_title         artist
# 2004       Feeling Calm  Phone Down - Dodge & Fuski Remix     Lost Kings
# 1194       Feeling Calm                          Trumpets   Jason Derulo
# 780        Feeling Calm                         Hot N*gga  Bobby Shmurda
# 1361  Feeling energetic                          Stardust       Kevin Oh
# 1117       Feeling Calm                       Shaky Shaky   Daddy Yankee

# %% [markdown]
# ## Yeah the model successfully clustered the songs in different mood groups

# %% [markdown]
# ### Lets begin classifying the song the person is listening to, to these mood groups so that can come to know the mood of the person based on the somg

# %%
## We will try classifiying the songs using different classifiers and then using ensemble learning will try to vote and use the maximum accuracy
#Start by importing the required libraries

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.multiclass import unique_labels

# %%
## Detecting the features and the labels
X = features.iloc[:,[0,1,2,3,4]]
y = features.iloc[:,5]
X.head()
# Out:
#      acousticness  danceability  liveness  loudness  speechiness
# 38       0.012800         0.747    0.1260  0.852699       0.1260
# 989      0.001900         0.468    0.4090  0.854254       0.0570
# 461      0.000022         0.657    0.0525  0.865477       0.0297
# 695      0.029600         0.907    0.1050  0.745349       0.0549
# 141      0.001020         0.798    0.0271  0.816163       0.2630

# %%
y.head()
# Out:
# 38     Feeling energetic
# 989        Feeling Happy
# 461    Feeling energetic
# 695    Feeling energetic
# 141         Feeling Calm
# Name: cluster_labels, dtype: object

# %% [markdown]
# ## Splitting the training and text set

# %%
#Performed splitting having 30% test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30,random_state=1)

# %% [markdown]
# We will try classifying the song to the dance type using different classifiers and will even use different ensemble learning methods like voting classifier,bagging,boosting,random forest and will see which is giving the most accurate result

# %% [markdown]
# ## Ensemble Learning (Voting Classifier)

# %%
## Classification using Voting Classifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score

# %%
##Instantiate the classifier
dt = DecisionTreeClassifier(max_depth=2,random_state=1)
lr = LogisticRegression(random_state=1)
knn = KNeighborsClassifier()

# %%
##Fitting the model to training data and comparing the accuracy of the classifiers
Classifiers = {'LogisticRegression':lr,'KNearestNeighbors':knn,'DecisionTreeClassifier':dt}
for clf_name,clf in Classifiers.items():
  clf.fit(X_train,y_train)
  y_pred = clf.predict(X_test)
  print('{:s}:{:.3f}'.format(clf_name,accuracy_score(y_test,y_pred)))
# Out:
# LogisticRegression:0.937
# KNearestNeighbors:0.960
# DecisionTreeClassifier:0.828

# %%
X_test.head()
# Out:
#       acousticness  danceability  liveness  loudness  speechiness
# 396         0.3040         0.785    0.0824  0.732388       0.0416
# 826         0.0169         0.374    0.3220  0.900457       0.2950
# 18          0.3140         0.713    0.1170  0.804971       0.2410
# 1091        0.2090         0.660    0.1120  0.864288       0.1700
# 964         0.2110         0.418    0.1870  0.858951       0.0295

# %%
##Using Voting Classifier
vc = VotingClassifier(estimators = Classifiers.items())
vc.fit(X_train,y_train)
y_pred = vc.predict(X_test)
print('Voting Classifier:{:.3f}'.format(accuracy_score(y_test,y_pred)))
# Out:
# Voting Classifier:0.949

# %%
##Evaluating Accuracy Using Confusion Matrix And Classification Report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 53   0  15   2]
#  [  0 102   8   0]
#  [  1   1 358   1]
#  [  0   1   2  62]]
#                     precision    recall  f1-score   support
#
#       Feeling Calm       0.98      0.76      0.85        70
#      Feeling Happy       0.98      0.93      0.95       110
#  Feeling energetic       0.93      0.99      0.96       361
# Feeling passionate       0.95      0.95      0.95        65
#
#           accuracy                           0.95       606
#          macro avg       0.96      0.91      0.93       606
#       weighted avg       0.95      0.95      0.95       606

# %% [markdown]
# ## Bagging Classifier

# %%
##It trains different models using the same algorithm for different parts of the training set 
from sklearn.ensemble import BaggingClassifier
seed=1
knn = KNeighborsClassifier()
bc = BaggingClassifier(base_estimator=knn,n_estimators=300,n_jobs=-1,random_state=3222)

# %%
##Fitting data to train and test and predicting
bc.fit(X_train,y_train)
y_pred = bc.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.9587458745874587

# %%
##Evaluating Accuracy Using Confusion Matrix And Classification Report
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 60   1   8   1]
#  [  0 102   8   0]
#  [  1   2 356   2]
#  [  0   0   2  63]]
#                     precision    recall  f1-score   support
#
#       Feeling Calm       0.98      0.86      0.92        70
#      Feeling Happy       0.97      0.93      0.95       110
#  Feeling energetic       0.95      0.99      0.97       361
# Feeling passionate       0.95      0.97      0.96        65
#
#           accuracy                           0.96       606
#          macro avg       0.97      0.93      0.95       606
#       weighted avg       0.96      0.96      0.96       606

# %% [markdown]
# ## Random Forest Classifier

# %%
#Instantiating the model
##Basically Random Forest is an ensemble method where the base estimator is the decision tree
rf = RandomForestClassifier(n_estimators=300,min_samples_leaf=0.12,random_state=1)
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8217821782178217

# %%
##Evaluating the model
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[  0  12  56   2]
#  [  0 104   6   0]
#  [  0  17 343   1]
#  [  0   5   9  51]]
#                     precision    recall  f1-score   support
#
#       Feeling Calm       0.00      0.00      0.00        70
#      Feeling Happy       0.75      0.95      0.84       110
#  Feeling energetic       0.83      0.95      0.89       361
# Feeling passionate       0.94      0.78      0.86        65
#
#           accuracy                           0.82       606
#          macro avg       0.63      0.67      0.65       606
#       weighted avg       0.73      0.82      0.77       606
# C:\Users\Pravallika Myneni\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Pravallika Myneni\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Pravallika Myneni\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Extracting Data from Spotify

# %%
import spotipy
import spotipy.util as util
import requests

# %%
def get_id(track_name: str, token: str) -> str:
    headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + token,
    }
    params = [
    ('q', track_name),
    ('type', 'track'),
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', 
                    headers = headers, params = params, timeout = 5)
        json = response.json()
        first_result = json['tracks']['items'][0]
        track_id = first_result['id']
        return track_id
    except:
        return None


def get_features(track_id: str, token: str) -> dict:
    sp = spotipy.Spotify(auth=token)
    try:
        features = sp.audio_features([track_id])
        return features[0]
    except:
        return None

username = 'Pravallika'
client_id ='43bc2d5a2e07480584f7ea9fe2effdd4'
client_secret = '107c3080b8634f7fa3b46f35eb64655b'
redirect_uri = ' http://localhost:8888/callback'
scope = 'user-read-recently-played'

# %%
token = util.prompt_for_user_token(username=username, scope=scope, client_id=client_id,client_secret=client_secret,redirect_uri=redirect_uri)
print(token)

# %%
res = {key: song_features[key] for key in song_features.keys() 
                               & {'acousticness','danceability','liveness','loudness','speechiness'}}
k={}
for i in res.keys():
    k[i]=[res[i]]
df=pd.DataFrame(k)    
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-2a96e3488261> in <module>
# ----> 1 res = {key: song_features[key] for key in song_features.keys()
#       2                                & {'acousticness','danceability','liveness','loudness','speechiness'}}
#       3 k={}
#       4 for i in res.keys():
#       5     k[i]=[res[i]]
#
# NameError: name 'song_features' is not defined

# %%
y_ans = bc.predict(df)
print('It seems like you are {:s}'.format(y_ans[0]))
# Out:
# It seems like you are Feeling Happy

# %%
y_ans_songs = pd.DataFrame(features[features['cluster_labels']==y_ans[0]].song_title)
print('Here is a list of some more songs you may like')
y_ans_songs.head()
# Out:
# Here is a list of some more songs you may like
#                   song_title
# 1550              Angel Eyes
# 1856                Lost Boy
# 1521           For Wee Folks
# 382              Indian Food
# 1540  Good Morning Heartache
